# %% [markdown]
# ## Exploratory Data Analysis on Titles.csv

# %% [markdown]
# #### Importing libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### UPLOADING DATASET

# %%
data = pd.read_csv(r"C:\Users\akinrotimi\python files\EDA\titles.csv")
data
# Out:
#              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 3      tm127384            Monty Python and the Holy Grail  MOVIE
# 4      tm120801                            The Dirty Dozen  MOVIE
# ...         ...                                        ...    ...
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# ...

# %%
data.head(10)
# Out:
#          id                                title   type  \
# 0  ts300399  Five Came Back: The Reference Films   SHOW
# 1   tm84618                          Taxi Driver  MOVIE
# 2  tm154986                          Deliverance  MOVIE
# 3  tm127384      Monty Python and the Holy Grail  MOVIE
# 4  tm120801                      The Dirty Dozen  MOVIE
# 5   ts22164         Monty Python's Flying Circus   SHOW
# 6   tm70993                        Life of Brian  MOVIE
# 7   tm14873                          Dirty Harry  MOVIE
# 8  tm119281                     Bonnie and Clyde  MOVIE
# 9   tm98978                      The Blue Lagoon  MOVIE
#
#                                          description  release_year  \
# 0  This collection includes 12 World War II-era p...          1945
# 1  A mentally unstable Vietnam War veteran works ...          1976
# 2  Intent on seeing the Cahulawassee River before...          1972
# 3  King Arthur, accompanied by his squire, recrui...          1975
# ...

# %%
data.tail(15)
# Out:
#              id                                      title   type  \
# 5835   tm985747                               I Missed You  MOVIE
# 5836   tm959213                                  My Amanda  MOVIE
# 5837  tm1040816                Momshies! Your Soul is Mine  MOVIE
# 5838  tm1053409                       Happiness Ever After  MOVIE
# 5839  tm1165179                                Kongsi Raya  MOVIE
# 5840  tm1216735                            Sun of the Soil  MOVIE
# 5841   tm985215                       Princess 'Daya'Reese  MOVIE
# 5842  tm1066324          Super Monsters: Once Upon a Rhyme  MOVIE
# 5843  tm1097142                                   My Bride  MOVIE
# 5844  tm1074617              Bling Empire - The Afterparty  MOVIE
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# ...

# %% [markdown]
# ####  DATA EXPLORATION AND ANALYSIS

# %% [markdown]
# The line of code below gives a summary of the data set and information on the dataset such as:
# -The number of rows and columns in the dataset.
# -The column names and their respective data types.
# -The count of non-null values in each column.
# -The memory usage of the dataset.

# %%
data.info
# Out:
# <bound method DataFrame.info of              id                                      title   type  \
# 0      ts300399        Five Came Back: The Reference Films   SHOW
# 1       tm84618                                Taxi Driver  MOVIE
# 2      tm154986                                Deliverance  MOVIE
# 3      tm127384            Monty Python and the Holy Grail  MOVIE
# 4      tm120801                            The Dirty Dozen  MOVIE
# ...         ...                                        ...    ...
# 5845  tm1014599                                  Fine Wine  MOVIE
# 5846   tm898842                                C/O Kaadhal  MOVIE
# 5847  tm1059008                                    Lokillo  MOVIE
# 5848  tm1035612  Dad Stop Embarrassing Me - The Afterparty  MOVIE
# 5849   ts271048         Mighty Little Bheem: Kite Festival   SHOW
#
#                                             description  release_year  \
# 0     This collection includes 12 World War II-era p...          1945
# ...

# %%
data.shape
#(rows, columns)
# Out:
# (5850, 15)

# %%
df.size
#multiplies the number of rows by the number of column:for a pandas DataFrame includes missing or null values in the calculation
# Out:
# 87750

# %%
data.size
# the above line of code multiplies the number of rows by the number of column excluding the ones with null or missing: for a NumPy array counts all elements value
# Out:
# 87750

# %%
data.ndim
#checks for the dimension of the dataframe
# Out:
# 2

# %%
data.describe()
# Out:
#        release_year      runtime      seasons   imdb_score    imdb_votes  \
# count   5850.000000  5850.000000  2106.000000  5368.000000  5.352000e+03
# mean    2016.417094    76.888889     2.162868     6.510861  2.343938e+04
# std        6.937726    39.002509     2.689041     1.163826  9.582047e+04
# min     1945.000000     0.000000     1.000000     1.500000  5.000000e+00
# 25%     2016.000000    44.000000     1.000000     5.800000  5.167500e+02
# 50%     2018.000000    83.000000     1.000000     6.600000  2.233500e+03
# 75%     2020.000000   104.000000     2.000000     7.300000  9.494000e+03
# max     2022.000000   240.000000    42.000000     9.600000  2.294231e+06
#
#        tmdb_popularity   tmdb_score
# count      5759.000000  5539.000000
# mean         22.637925     6.829175
# std          81.680263     1.170391
# min           0.009442     0.500000
# 25%           2.728500     6.100000
# 50%           6.821000     6.900000
# 75%          16.590000     7.537500
# ...

# %%
data.sample()
#to select a random sample
# Out:
#           id         title  type  \
# 236  ts20573  The IT Crowd  SHOW
#
#                                            description  release_year  \
# 236  Two I.T. nerds and their clueless female manag...          2006
#
#     age_certification  runtime                  genres production_countries  \
# 236             TV-14       25  ['comedy', 'european']               ['GB']
#
#      seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 236      5.0  tt0487831         8.5    149586.0           31.031       8.108

# %%
data.isnull().sum()
# Out:
# id                         0
# title                      1
# type                       0
# description               18
# release_year               0
# age_certification       2619
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 3744
# imdb_id                  403
# imdb_score               482
# imdb_votes               498
# tmdb_popularity           91
# tmdb_score               311
# dtype: int64

# %%
data.nunique()
# Out:
# id                      5850
# title                   5798
# type                       2
# description             5829
# release_year              63
# age_certification         11
# runtime                  202
# genres                  1726
# production_countries     452
# seasons                   26
# imdb_id                 5447
# imdb_score                80
# imdb_votes              3880
# tmdb_popularity         4889
# tmdb_score               394
# dtype: int64

# %%
data.index
# Out:
# RangeIndex(start=0, stop=5850, step=1)

# %%
data.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score'],
#       dtype='object')

# %%
data.memory_usage()
# Out:
# Index                     128
# id                      46800
# title                   46800
# type                    46800
# description             46800
# release_year            46800
# age_certification       46800
# runtime                 46800
# genres                  46800
# production_countries    46800
# seasons                 46800
# imdb_id                 46800
# imdb_score              46800
# imdb_votes              46800
# tmdb_popularity         46800
# tmdb_score              46800
# dtype: int64

# %%
data.dropna(inplace=True)

# %%
data.shape
# Out:
# (1667, 15)

# %%
data.nlargest(10,"imdb_score")
#outputs the top 10 'imdb_score' in descending order
# Out:
#            id                       title  type  \
# 216       ts4                Breaking Bad  SHOW
# 233    ts3371  Avatar: The Last Airbender  SHOW
# 3147  ts85398                  Our Planet  SHOW
# 1258  ts37660                  Reply 1988  SHOW
# 1886  ts78298                   My Mister  SHOW
# 3068  ts81120              The Last Dance  SHOW
# 3500  ts90621                Kota Factory  SHOW
# 165   ts28516                      Okupas  SHOW
# 243   ts11313                  DEATH NOTE  SHOW
# 653   ts32835             Hunter x Hunter  SHOW
#
#                                             description  release_year  \
# 216   When Walter White, a New Mexico chemistry teac...          2008
# 233   In a war-torn world of elemental magic, a youn...          2005
# 3147  Experience our planet's natural beauty and exa...          2019
# 1258  A nostalgic trip back to the late 1980s throug...          2015
# 1886  In a world that is less than kind, a young wom...          2018
# ...

# %%
data.isna().tail()
#True = missing values
# Out:
#          id  title   type  description  release_year  age_certification  \
# 5784  False  False  False        False         False              False
# 5785  False  False  False        False         False              False
# 5801  False  False  False        False         False              False
# 5819  False  False  False        False         False              False
# 5831  False  False  False        False         False              False
#
#       runtime  genres  production_countries  seasons  imdb_id  imdb_score  \
# 5784    False   False                 False    False    False       False
# 5785    False   False                 False    False    False       False
# 5801    False   False                 False    False    False       False
# 5819    False   False                 False    False    False       False
# 5831    False   False                 False    False    False       False
#
#       imdb_votes  tmdb_popularity  tmdb_score
# ...

# %%
duplicated_data = data.duplicated()
duplicated_data.describe()
# Out:
# count      1667
# unique        1
# top       False
# freq       1667
# dtype: object

# %%
duplicated_data.sum()
# Out:
# 0

# %%
data['age_certification'].value_counts()
#gives the count of the specified column name 'age_certification' in descending order excluding the missing values from the Series
# Out:
# TV-MA    822
# TV-14    417
# TV-PG    161
# TV-Y7    106
# TV-Y      87
# TV-G      74
# Name: age_certification, dtype: int64

# %%
data.corr()
# Out:
# C:\Users\akinrotimi\AppData\Local\Temp\ipykernel_8344\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                  release_year   runtime   seasons  imdb_score  imdb_votes  \
# release_year         1.000000  0.148395 -0.560456   -0.195005   -0.160576
# runtime              0.148395  1.000000 -0.134481    0.234882    0.085257
# seasons             -0.560456 -0.134481  1.000000    0.116403    0.201393
# imdb_score          -0.195005  0.234882  0.116403    1.000000    0.257452
# imdb_votes          -0.160576  0.085257  0.201393    0.257452    1.000000
# tmdb_popularity     -0.052432  0.074019  0.164014    0.087494    0.520398
# tmdb_score          -0.049391  0.000562  0.062248    0.342632    0.126829
#
#                  tmdb_popularity  tmdb_score
# ...

# %%
data.dtypes
#data types of the columns
# Out:
# id                       object
# title                    object
# type                     object
# description              object
# release_year              int64
# age_certification        object
# runtime                   int64
# genres                   object
# production_countries     object
# seasons                 float64
# imdb_id                  object
# imdb_score              float64
# imdb_votes              float64
# tmdb_popularity         float64
# tmdb_score              float64
# dtype: object

# %% [markdown]
# #### DOWNLOADING CLEANED .csv DATASET

# %%
data.to_csv(r'C:\Users\akinrotimi\Desktop\cleaned_data.csv')
#to export the cleaned dataset as a csv file to the specified path
